# %% [markdown]
# <a href="https://colab.research.google.com/github/Chithra-bit/Chithra-Devi-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([90, 85, 78, 92])

print(marks[3])
# Out:
# 92

# %%
import numpy as np

marks = np.array([90, 85, 78, 92, 88])

print(marks[1:5])
# Out:
# [85 78 92 88]

# %%
import numpy as np

marks = np.array([90, 85, 78, 92])
print(marks)
# Out:
# [90 85 78 92]

# %%
import numpy as np

marks = np.array([
    [90, 85, 78],
        [92, 88, 95]
        ])
print(marks)
# Out:
# [[90 85 78]
#  [92 88 95]]

# %%
def attendance(attendaed,total):
      return (attended / total) * 100

attended = int(input("classes attended: "))
total = int(input("Total classes: "))

precentage = attendance(attended,total)

print("attendance precentage =",round(precentage, 2), "%")
# Out:
# classes attended: 80
# Total classes: 100
# attendance precentage = 80.0 %
