# %% [markdown]
# <a href="https://colab.research.google.com/github/Chithra-bit/Chithra-Devi-/blob/main/Simple_function_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hello Everyone! ")
greet()
# Out:
# Hello Everyone!

# %%
def greet(name):
   print("Welcome", name)
greet("ChithraDevi")
# Out:
# Welcome ChithraDevi

# %%
def add(a,b):
  return a+b
result = add(100,80)
print(result)
# Out:
# 180
