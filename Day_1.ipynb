# %% [markdown]
# <a href="https://colab.research.google.com/github/Chithra-bit/Chithra-Devi-/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1 = float(input("Enter Mark 1: "))
Mark2 = float(input("Enter Mark 2: "))
Mark3 = float(input("Enter Mark 3: "))

Total = Mark1 + Mark2 + Mark3
Average = Total / 3

print("Total:", Total)
print("Average:", round(Average, 2))

if Average >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Mark 1: 50
# Enter Mark 2: 70
# Enter Mark 3: 30
# Total: 150.0
# Average: 50.0
# Pass

# %%
Mark1 = int(input("Enter Mark 1: "))
Mark2 = int(input("Enter Mark 2: "))
Mark3 = int(input("Enter Mark 3: "))

Total = Mark1 + Mark2 + Mark3
Average = Total / 3

print("Total:", Total)
print("Average:", Average)

if Average >= 90:
    print("Grade: A")
elif Average >= 50:
    print("Grade: B")
else:
    print("Grade: C")
# Out:
# Enter Mark 1: 80
# Enter Mark 2: 90
# Enter Mark 3: 95
# Total: 265
# Average: 88.33333333333333
# Grade: B

# %%
Expenses = [200, 280, 300, 150]

Total = sum(Expenses)

print("Expenses:", Expenses)
print("Total Expenses:", Total)
# Out:
# Expenses: [200, 280, 300, 150]
# Total Expenses: 930

# %%
def calculate_grade(score):
      if score >= 90:
              return 'S'
      elif score >= 75:
              return 'A'
      else:
              return 'F'
student_marks = {
             "Sahuban": 88,
    "Shabeeba": 92,
    "Azra": 70,
    "Ali": 95,
}
pass_count = 0
fail_count = 0
for student, mark in student_marks.items():
      grade = calculate_grade(mark)
      print(student, "-", mark, "-", grade)

      if grade == 'F':
          fail_count += 1
      else:
          pass_count += 1

print("Passed:", pass_count)
print("Failed:", fail_count)
# Out:
# Sahuban - 88 - A
# Shabeeba - 92 - S
# Azra - 70 - F
# Ali - 95 - S
# Passed: 3
# Failed: 1
