# %% [markdown]
# <a href="https://colab.research.google.com/github/Chithra-bit/Chithra-Devi-/blob/main/Project_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scores=[85,90,78,95,88]
total=sum(scores)
average=total/len(scores)
highest=max(scores)
lowest=min(scores)
print("total score:",total)
print("average score:",average)
print("highest score:",highest)
print("lowest score:",lowest)
# Out:
# total score: 436
# average score: 87.2
# highest score: 95
# lowest score: 78

# %%
sales=[1000,2000,3000,5000,7000]
total_sales=sum(sales)
average_sales=total_sales/len(sales)
highest_sales=max(sales)
lowest_sales=min(sales)
print("monthly sales::",sales)
print("total sales:",total_sales)
print("average sales:",average_sales)
print("highest_sales:",highest_sales)
print("lowest_sales:",lowest_sales)
# Out:
# monthly sales:: [1000, 2000, 3000, 5000, 7000]
# total sales: 18000
# average sales: 3600.0
# highest_sales: 7000
# lowest_sales: 1000
